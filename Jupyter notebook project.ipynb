# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Jose Gonzales
#
# current: Teacher. Desired: data scientist

# %% [markdown]
# <i> I am interested in data science because it is a rapidly growing fields with good career opportunitites

# %% [markdown]
# ### My code is supposed to find the product of 20 and 21

# %%
20*21
# Out:
# 420

# %% [markdown]
# <ol>
# <li> wake up
# <li> go to work
# <li> go home
# <li> sleep
# </ol>
#
# <ul>
# <li> chicken
# <li> pork
# <li> beef
# </ul>
#
# |Name|Date|Time|
# |-----|-----|-----|
# |James|Mar 6|2 PM|
# |Jessey|Oct 13|5 PM|
# |Ash|Jan 6| 4 AM|
